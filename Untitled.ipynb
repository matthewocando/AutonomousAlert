# %% [markdown]
# # Setup

# %%
#Run cell when working on colab
# !pip install -Uqq fastbook

# %%
import fastbook
fastbook.setup_book()

# %%
from fastbook import *
from fastai.vision.widgets import *
import matplotlib.pyplot as plt
import librosa
import librosa.display
import os
import warnings
import PIL

# %%
data_path = Path('/content/gdrive/MyDrive/ENEL 400/Data')

# %% [markdown]
# # Getting data ready

# %%
warnings.filterwarnings("ignore")

sgrams = []
sample_rates = []
graphs = []
for AUDIO_FILE in os.listdir(data_path/'Ambulance'):
  if filename.endswith(".mp3"):
    samples, sample_rate = librosa.load(data_path/'Ambulance'/AUDIO_FILE, sr=None);
    sgram = librosa.stft(samples)
    sgram_mag, _ = librosa.magphase(sgram)
    mel_scale_sgram = librosa.feature.melspectrogram(S=sgram_mag, sr=sample_rate)
    mel_sgram = librosa.amplitude_to_db(mel_scale_sgram, ref=np.min)
    sgrams.append(mel_sgram)
    sample_rates.append(sample_rate)
    graph = librosa.display.specshow(mel_sgram, sr=sample_rate);
    graphs.append(graph);
print("[DONE!]")
# Out:
# [DONE!]

# %%
warnings.filterwarnings("default")
from matplotlib.backends.backend_agg import FigureCanvasAgg as FigureCanvas
counter = 0
for sample_rate,sgram in zip(sample_rates,sgrams):
  fig = plt.Figure()
  canvas = FigureCanvas(fig)
  ax = fig.add_subplot(111)
  p = librosa.display.specshow(sgram, sr=sample_rate, ax=ax)
  fig.savefig(data_path/'Ambulance_spec'/(str(counter).zfill(4)+'.png'))
  counter = counter + 1

# %%
warnings.filterwarnings("ignore")

sgrams = []
sample_rates = []
graphs = []
for AUDIO_FILE in os.listdir(data_path/'Other'):
  if filename.endswith(".mp3"):
    samples, sample_rate = librosa.load(data_path/'Other'/AUDIO_FILE, sr=None);
    sgram = librosa.stft(samples)
    sgram_mag, _ = librosa.magphase(sgram)
    mel_scale_sgram = librosa.feature.melspectrogram(S=sgram_mag, sr=sample_rate)
    mel_sgram = librosa.amplitude_to_db(mel_scale_sgram, ref=np.min)
    sgrams.append(mel_sgram)
    sample_rates.append(sample_rate)
    graph = librosa.display.specshow(mel_sgram, sr=sample_rate);
    graphs.append(graph);
print("[DONE!]")
# Out:
# [DONE!]

# %%
warnings.filterwarnings("default")
from matplotlib.backends.backend_agg import FigureCanvasAgg as FigureCanvas
counter = 0
for sample_rate,sgram in zip(sample_rates,sgrams):
  fig = plt.Figure()
  canvas = FigureCanvas(fig)
  ax = fig.add_subplot(111)
  p = librosa.display.specshow(sgram, sr=sample_rate, ax=ax)
  fig.savefig(data_path/'Other_spec'/(str(counter).zfill(4)+'.png'))
  counter = counter + 1
